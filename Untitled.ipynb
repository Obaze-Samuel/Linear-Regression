# %% [markdown]
# # Multiple Linear Regression Analysis on Student Performance
# This notebook analyzes the impact of various factors on student performance using multiple linear regression.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\obaze.samuel\\Downloads\\Student_Performance.csv")
df.head()
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %% [markdown]
# **3. Replacing Categorical Values**
#
# The "Extracurricular Activities" column contains categorical values ("Yes" or "No"). These are replaced with numerical values (1 for "Yes" and 0 for "No").

# %%
df["Extracurricular Activities"] = df["Extracurricular Activities"].replace({"Yes": 1, "No": 0})
df.head()
# Out:
# C:\Users\obaze.samuel\AppData\Local\Temp\ipykernel_23976\83537241.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["Extracurricular Activities"] = df["Extracurricular Activities"].replace({"Yes": 1, "No": 0})
#    Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0              7               99                           1            9
# 1              4               82                           0            4
# 2              8               51                           1            7
# 3              5               52                           1            5
# 4              7               75                           0            8
#
#    Sample Question Papers Practiced  Performance Index
# ...

# %%
df.describe().T
# Out:
#                                     count     mean        std   min   25%  \
# Hours Studied                     10000.0   4.9929   2.589309   1.0   3.0
# Previous Scores                   10000.0  69.4457  17.343152  40.0  54.0
# Extracurricular Activities        10000.0   0.4948   0.499998   0.0   0.0
# Sleep Hours                       10000.0   6.5306   1.695863   4.0   5.0
# Sample Question Papers Practiced  10000.0   4.5833   2.867348   0.0   2.0
# Performance Index                 10000.0  55.2248  19.212558  10.0  40.0
#
#                                    50%   75%    max
# Hours Studied                      5.0   7.0    9.0
# Previous Scores                   69.0  85.0   99.0
# Extracurricular Activities         0.0   1.0    1.0
# Sleep Hours                        7.0   8.0    9.0
# Sample Question Papers Practiced   5.0   7.0    9.0
# Performance Index                 55.0  71.0  100.0

# %% [markdown]
# **4. Linearity Test**
#
# The following plots visualize the relationship between each independent variable and the target variable ("Performance Index") to assess linearity.

# %%
fig,axs = plt.subplots(2,3, figsize = (14,6))
fig.subplots_adjust(hspace = 0.5,wspace = 0.5)
axs = axs.ravel()

for index, column in enumerate(df.columns):
    if index < 5: # Adjust loop to avoid exceeding the number of subplots
        axs[index].set_title(f"{column} Vs Performance Index", fontsize = 8)  # Reduced fontsize
        axs[index].scatter(x=df[column],y = df["Performance Index"], color = "red", edgecolor ="k", s = 5)
        axs[index].grid(True)
        

fig.delaxes(axs[5])
    
fig.tight_layout(pad=1)
plt.show()

# %% [markdown]
# It appears that a significant amount of Hours studied data and Previous Scores has linear relationship with Performance Index
# Based on these findings, is there enough linearity present to apply a linear regression model?

# %% [markdown]
# **6. Multicollinearity Test**
#
# * **Pairplot:** A pairplot is used to visualize relationships between variables.

# %%
Mp = sns.pairplot(data = df.drop("Performance Index", axis = 1),kind = "scatter")
Mp.fig.set_size_inches(9,9)
